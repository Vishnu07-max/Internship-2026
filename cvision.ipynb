# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
image = np.full((16, 16,3), 250,dtype='uint8')
image[4:10,4:5]=[255,0,0]
image[4:10,5:6]=[225,225,0]
plt.imshow(image, cmap='jet')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
image = np.full((160, 160,3), 250,dtype='uint8')
image[40:100,40:50]=[0,0,225]
image[40:100,50:60]=[225,225,0]
cv2.imshow('image',image)
cv2.imwrite('image.jpg',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = np.full((16, 16,3),250, dtype='uint8')
image[4:10,4:5]=[157,193,131]
image[4:10,5:6]=[255,119,130]
image[4:10,6:7]=[255,244,79]
cv2.imshow('image', image)
cv2.imwrite('image.jpg', image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = np.full((8, 16,3),100, dtype='uint8')
image[1:3,2:10]=[244,96,48]
image[3:5,2:10]=[255,255,255]
image[5:7,2:10]=[0,100,0]
plt.imshow(image, cmap='jet')
plt.show()

# %%
import cv2
import numpy as np

# Create a sample image (500x500 with gradient colors)
image = np.zeros((500, 500, 3), dtype=np.uint8)
for i in range(500):
    for j in range(500):
        image[i, j] = [i % 256, j % 256, (i+j) % 256]

# Save as demo.jpg
cv2.imwrite('demo.jpg', image)
print("demo.jpg created successfully!")
# Out:
# demo.jpg created successfully!

# %%
image=cv2.imread('demo.jpg',0)
image=cv2.GaussianBlur(image,(5,5),0)
threshold_image,th=cv2.threshold(image,157,255,cv2.THRESH_TOZERO)
cv2.imshow('image',th)
cv2.waitKey(1000)
cv2.destroyAllWindows()

# %%
edge_detected_image=cv2.Canny(image,100,200)
cv2.imshow('image',edge_detected_image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
image=cv2.imread('lio2.jpg')
cv2.imshow('Image',image)
cv2.waitKey(5000)
# Out:
# -1

# %%
pip list | findstr opencv
# Out:
# opencv-python             5.0.0.93
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-python -y
# Out:
# Found existing installation: opencv-python 5.0.0.93
# Uninstalling opencv-python-5.0.0.93:
#   Successfully uninstalled opencv-python-5.0.0.93
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'D:\internship 2026\.venv\Lib\site-packages\~v2'.
# You can safely remove it manually.

# %%
pip uninstall opencv-contrib-python -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv-contrib-python as it is not installed.

# %%
pip uninstall opencv-python-headless -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv-python-headless as it is not installed.

# %%
pip uninstall opencv -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv as it is not installed.

# %%
pip install opencv-python==4.12.0.88
# Out:
# Collecting opencv-python==4.12.0.88
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python==4.12.0.88)
#   Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.0 MB 4.7 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/39.0 MB 6.5 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/39.0 MB 11.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/39.0 MB 12.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.8/39.0 MB 16.6 MB/s eta 0:00:02
#    ------------------- -------------------- 19.4/39.0 MB 16.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.3/39.0 MB 15.7 MB/s eta 0:00:02
#    -------------------------- ------------- 25.4/39.0 MB 15.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.6/39.0 MB 15.7 MB/s eta 0:00:01
#    ------------------------------ --------- 30.1/39.0 MB 15.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/39.0 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.0 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 15.7 MB/s  0:00:02
# Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.6 MB 16.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.6 MB 16.0 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 16.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 14.7 MB/s  0:00:00
# Installing collected packages: numpy, opencv-python
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.5.0
#
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-2.5.0:
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-2.5.0
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    ---------------------------------------- 2/2 [opencv-python]
#
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'D:\internship 2026\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\internship 2026\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
import cv2

print(cv2.__version__)
print(hasattr(cv2, "CascadeClassifier"))
# Out:
# 5.0.0
# False

# %%
pip list | findstr opencv
# Out:
# opencv-python             4.12.0.88
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-python -y
# Out:
# Found existing installation: opencv-python 4.12.0.88
# Uninstalling opencv-python-4.12.0.88:
#   Successfully uninstalled opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-contrib-python -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv-contrib-python as it is not installed.

# %%
pip uninstall opencv-python-headless -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv-python-headless as it is not installed.

# %%
pip uninstall opencv -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping opencv as it is not installed.

# %%
pip install opencv-python==4.12.0.88
# Out:
# Collecting opencv-python==4.12.0.88
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in .\.venv\Lib\site-packages (from opencv-python==4.12.0.88) (2.2.6)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

print(cv2.__version__)
print(hasattr(cv2, "CascadeClassifier"))
# Out:
# 5.0.0
# False

# %%
import cv2

print(cv2.__version__)
print(hasattr(cv2, "CascadeClassifier"))
# Out:
# 4.12.0
# True

# %%
import cv2
import numpy as np
image=cv2.imread('lio2.jpg')
model=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces=model.detectMultiScale(image)
print(faces)
for face in faces:
    x, y, w, h = face
    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 3)
cv2.imwrite('output.jpg', image)
# Out:
# [[190 149 176 176]]
# True

# %%
#cifer10 data using CNN
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#   2506752/170498071 ━━━━━━━━━━━━━━━━━━━━ 9:21:44 201us/step
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[8], line 6
#       2 import tensorflow as tf
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense,Conv2D
#       5 from keras.datasets import cifar10
# ----> 6 (x_train,y_train),(x_test,y_test)=cifar10.load_data()
#
# File d:\internship 2026\.venv\Lib\site-packages\keras\src\datasets\cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
#      81 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File d:\internship 2026\.venv\Lib\site-packages\keras\src\utils\file_utils.py:395, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     393 try:
#     394     try:
# --> 395         urlretrieve(origin, download_target, DLProgbar())
#     396     except urllib.error.HTTPError as e:
#     397         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:242, in urlretrieve(url, filename, reporthook, data)
#     239 if reporthook:
#     240     reporthook(blocknum, bs, size)
# --> 242 while block := fp.read(bs):
#     243     read += len(block)
#     244     tfp.write(block)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
model
